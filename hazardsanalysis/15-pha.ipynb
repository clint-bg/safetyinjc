# %% [markdown]
# # DHA and PHA

# %% [markdown]
# ```{seealso} Learning Outcomes
# - Know the difference between a FMEA, HAZOP, and PHA
# - Know the difference between a DHA and a PHA
# ```

# %% [markdown]
# ```{note} Reading
# - Foundations of Spiritual and Physical Safety: with Chemical Processes; Chapter 5, Sections 2.4-3
# ```
