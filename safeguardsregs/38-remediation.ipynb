# %% [markdown]
# # Remediation

# %% [markdown]
# ```{seealso} Learning Outcomes
# - Identify and detail various environmental remediation processes, such as soil washing, vitrification, pump and treat, and bioremediation.
# - Understand the fate and transport of contaminants through environmental cycles like the hydrologic cycle.
# - Discuss the relationship between environmental remediation principles and spiritual "cleaning" through the Atonement of Jesus Christ.
# ```

# %% [markdown]
# ```{note} Reading
# - Foundations of Spiritual and Physical Safety: with Chemical Processes; Section X11.5
# - https://www.churchofjesuschrist.org/study/general-conference/2006/10/the-atonement-can-clean-reclaim-and-sanctify-our-lives?lang=eng
# ```

# %% [markdown]
# ## Spiritual Healt
# The Atonement of Jesus Christ Can Clean, Reclaim, and Sanctify Our Lives

# %% [markdown]
# https://www.churchofjesuschrist.org/study/general-conference/2006/10/the-atonement-can-clean-reclaim-and-sanctify-our-lives?lang=eng

# %% [markdown]
# ## Fate and Transport

# %% [markdown]
# ### Thought Experiment - Tree Leaves
# What happens to tree leaves?
#
# Do they not just keep building up in layers?
#
# Wouldn't the tree's just eventually be buried in leaves?

# %% [markdown]
# ### Thought Experiment - Tire Tread

# %% [markdown]
# Wear does all the tire tread go from use of millions of tires?
#
# Why doesn't it build up on the highway's or surroundings?
#
# How are those pieces transported?

# %% [markdown]
# ### Hydrologic Cycle

# %% [markdown]
# Water moves through the air, on the ground, and in the ground. It rains, water flows downhill on the surface, and water infiltrates into and out of the ground (aquifers).

# %% [markdown]
# Water is a universal solvent, and it can dissolve many substances. Water can also carry substances in solution, suspension, or as a colloid. Some of those substances are toxic.

# %% [markdown]
# We depend on water for drinking, agriculture, and industry.

# %% [markdown]
# ```{figure} https://github.com/clint-bg/safetyinjc/blob/main/supportfiles/hydrologic.jpg?raw=trueg
# :width: 600px
# :alt: Water Cycle
# :label: fig-watercycle
#
# Image of the water cycle. See also the USGS website at https://water.usgs.gov/edu/watercycle.html.
# ```

# %% [markdown]
# Image source: https://www.sciencefacts.net/water-cycle.html

# %% [markdown]
# ### Fate Processes

# %% [markdown]
# ```{figure}  https://github.com/clint-bg/safetyinjc/blob/main/supportfiles/fate.png?raw=trueg
# :width: 710px
# :alt: Fate Processes
# :label: fig-fate
#
# Image of fate processes.
# ```

# %% [markdown]
# ## Environmental Remediation

# %% [markdown]
# Remediation: the action of reversing or stopping environmental damage.

# %% [markdown]
# ### Soil Washing
#
# The soil is excavated and washed with water or other solvents to remove contaminants. The water is then treated to remove the contaminants.

# %% [markdown]
# ```{figure} https://github.com/clint-bg/safetyinjc/blob/main/supportfiles/washing.png?raw=trueg
# :width: 650px
# :alt: Soil Washing Process
# :label: fig-soilwashing
#
# Remediation process with washing and scrubbing of gases.
# ```

# %% [markdown]
# ### Demonstration
# 500mL syring and a makeshift sand charcoal filter showing how large particles are screened but smaller molecules like dyes are not or that those smaller molecules can be washed or eluded out of the makeshift filter.

# %% [markdown]
# ### Soil Roasting/ Incineration
#
# Soil roasting is a thermal treatment process that uses heat to remove contaminants from soil.

# %% [markdown]
# ```{figure} https://github.com/clint-bg/safetyinjc/blob/main/supportfiles/roasting.png?raw=trueg
# :width: 601px
# :alt: Soil Roasting Process
# :label: fig-soilroasting
#
# Image of aa soil roasting process.
# ```

# %% [markdown]
# ### Vitrification or Encapsulation
#
# Vitrification is the process of converting a material into a glass-like substance

# %% [markdown]
# ```{figure} https://github.com/clint-bg/safetyinjc/blob/main/supportfiles/vitrification.png?raw=trueg
# :width: 502px
# :alt: Vitrification Process
# :label: fig-vitrification
#
# Image of a vitrification process.
# ```

# %% [markdown]
# ### Video on Vitrification at PNNL
# https://www.youtube.com/watch?v=l-3we_QTK24

# %% [markdown]
# ### Landfilling
#
# Contaminated soil is excavated and placed in a landfill.

# %% [markdown]
# ```{figure} https://github.com/clint-bg/safetyinjc/blob/main/supportfiles/landfilling.png?raw=trueg
# :width: 803px
# :alt: landfill
# :label: landfill
#
# Image with layer details and barriers at a landfill.
# ```

# %% [markdown]
# Double lining with FML (Flexible Membrane Liners) and a dense clay layer is common practice to prevent leachate from contaminating groundwater.

# %% [markdown]
# ### Pump and Treat
#
# Groundwater is pumped to the surface and treated to remove the contaminants.

# %% [markdown]
# ### Volatilization
#
# Volatilization is the process of converting a solid or liquid into a gas.

# %% [markdown]
# ```{figure} https://github.com/clint-bg/safetyinjc/blob/main/supportfiles/volitile.png?raw=trueg
# :width: 600px
# :alt: volatilization
# :label: volatilization
#
# Drawing of a volatilization process.
# ```

# %% [markdown]
# ### Bioremediation
#
# Bio-remediation is the use of living organisms to clean up contaminated soil and water. The organisms can be bacteria, fungi, or plants. For example, some bacteria can break down oil into carbon dioxide and water.

# %% [markdown]
# ## Remediation Example

# %% [markdown]
# Mt. Trashmore in Virginia Beach, Virginia, is a former landfill that has been turned into a park. The park is built on top of the landfill, which has been capped with a layer of soil and grass. The park has a lake, playgrounds, and walking trails.

# %% [markdown]
# ## Example Problems

# %% [markdown]
# Which of the following methods would you choose to remediate a gasoline leak from an underground storage tank that has reached a water aquifer? Explain your reasons.
# - a.  Soil washing
# - b. Soil roasting/incineration
# - c. Bioremediation/landfarming
# - d. Stabilization and solidification, e.g., vitrification
# - e. Landfill
# - f. Pump and treat
# - g. Volitalization (soil vapor extraction or in situ air sparging)

# %% [markdown]
# Which of the following methods would you choose to remediate heavy metal contamination of a small volume of soil? Explain your reasons.
# - a. Soil washing
# - b. Soil roasting/incineration
# - c. Bioremediation/landfarming
# - d. Stabilization and solidification, e.g., vitrification
# - e. Landfill
# - f. Pump and treat
# - g. Volitalization (soil vapor extraction or in situ air sparging)

# %% [markdown]
# ```{warning} Action Items
# 1. Research a Superfund site near your home and provide a brief summary of the hazards and the cleanup progress achieved. Include a cleanup method that could be used in addition to the one being used.
# 2. How could Jesus Christ act as a Remediator to clean up the contamination (or provide comfort in the struggles) in your life?
# ```
