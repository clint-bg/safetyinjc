# %% [markdown]
# # Relief Valve Sizing

# %% [markdown]
# ```{seealso} Learning Outcomes
# - Perform preliminary sizing calculations of a relief valve for gas flow scenarios.
# ```

# %% [markdown]
# ```{note} Reading
# - Foundations of Spiritual and Physical Safety: with Chemical Processes; Section VII.3.1.
# ```

# %% [markdown]
# In the orifice flow lecture, we reviewed estimated flows through an orifice for gases, liquids, and two-phase flow. Those equations can be used to size a relief valve to prevent the pressure from exceeding a certain value. Solving the mass or mole balance equations in such scenarios can often be completed in a straight forward way.
#
# Important parameters for estimating the internal pressure to ensure the maximum pressure allowed isn't exceeded include:
# - the generation rate of the gases from the failure mode that need to be vented
# - the size of the relief valve

# %% [markdown]
# The American Petroleum Institute publishes the API 520 which is a standard for sizing and selection of relief devices. The newest edition is the 10th edition and it is 509 dollars on their webstore: https://www.apiwebstore.org/standards/520__Part_1 . Although I don't have the most recent edition, an estimate for the needed area for gas flow is by the below equation.

# %% [markdown]
# ### API 520 Equation in SI units
#
# $$
# A = \frac{W}{C\cdot K_d \cdot P_1 \cdot K_b \cdot K_c}\sqrt{\frac{T\cdot Z}{M}}
# $$
#
# where $A$ is the vent area in mm, $W$ is the mass flow through the vent in kg/hr, $P_1$ is the upstream relieving pressure (set pressure + overpressure + atmospheric pressure) in absolute pressure in kPa, T is the temperature in K, Z is the compressibility of the gases (1), M is the molecular weight of the gases in gm/mol, C is a value incorporating the heat capacity ratio and unit conversion and has a value here of 0.027. $K_d$ is the coefficient of discharge equal to 0.9. $K_b$ and $K_c$ are other coefficients depending on downstream resistance or other configurations and are equal to 1 in this case.

# %% [markdown]
# ### Gas Flow Through an Orifice (Theoretical)
#
# Reproduced here is estimated the flow of a gas through an orifice from the orifice flow lecture. It is also derived from an energy balance assuming adiabatic and frictionless flow. The flow is characterized by the pressure ratio, $P_o/P_{atm}$ and associated Mach number, $Ma$. $P_o$ is the absolute pressure of the volume. The Mach number can be found from:
#
# $$
# Ma = \text{min} \left(1, \sqrt{\frac{2}{\gamma - 1}\left(\left(\frac{P_o}{P_{atm}}\right)^{\frac{\gamma - 1}{\gamma}} - 1\right)}\right)
# $$
#
# where $\gamma$ is the ratio of specific heats (1.4 for air). The flow is choked when $Ma = 1$ and unchoked when $Ma < 1$.
#
# The molar flow rate is given by:
#
# $$
# \dot{n} = P_o A C_d \sqrt{\frac{\gamma}{R T M_w}} Ma \left[ 1+\frac{(\gamma-1)}{2}Ma^2\right]^{\frac{\gamma+1}{2-2\gamma}}
# $$
#
# where $R$ is the gas constant and $T$ is the temperature, $P_o$ is the absolute pressure inside the vessel, $C_d$ is the discharge coefficient (typically about 0.9). If you use all SI units (Pascal, meters, kilograms, mole: so pressure in pascal, area in meters, R in J/mol/K, and Mw in kg/mol), you'll get mole per second for $\dot{n}$. See Perry's Handbook for Chemical Engineers Equation 6-118 for more information.

# %% [markdown]
# Relief valve sizing in some instances does required verification with actual flow per the AMSE Boiler and Pressure Vessel Code.

# %% [markdown]
# ```{note}
#
# See in-class examples
#
# Download a pdf of the example using freeform here: https://github.com/clint-bg/safetyinjc/blob/main/supportfiles/GasFlowExample311.pdf
# ```

# %% [markdown]
# ## In Class Example: Venting CO2 from 2L Bottle

# %% [markdown]
# A two liter bottle is half filed with water. There is a relief valve on the top designed to relieve at 60 psig with a flow of 61 scfm. What is the flow rate of CO2 through the relieve per the above equations?

# %%
import numpy as np

# %%
#fist find the Mach number
gamma = 1.3 #specific heat capacity ratio for CO2, estimate
P1 = 60 + 12.5 #initial pressure, estimate, psia
Patm = 12.5 # atmospheric pressure, psia
Ma = min(1, np.sqrt(2/(gamma-1)*((P1/Patm)**((gamma-1)/gamma)-1))) #Mach number

# %%
Ma
# Out:
# 1

# %%
#now calculate the molar flow rate
R = 8.314 # gas constant, J/(mol*K)
Temp = 295 # temperature, K
Area = np.pi/4*(1/4*0.0254)**2 # area of the pipe, m^2
Cd = 0.9 # discharge coefficient
Mw = 0.04401 # molar mass of CO2, kg/mol
# molar flow rate, mol/s
ndot = P1*6894.76*Area*Cd*np.sqrt(gamma/(R*Temp*Mw))*Ma*(1+(gamma-1)/2*Ma**2)**((gamma+1)/(2-2*gamma)) 
print(f'The molar flow rate is {ndot:0.2f} mol/s')
# Out:
# The molar flow rate is 0.92 mol/s

# %%
#now convert that molar flow rate into scfm, PV = nRT
Tstandard = 298.15 # standard temperature, K
Pstandard = 101325 # standard pressure, Pa
scmps = ndot*R*Tstandard/Pstandard #units of m^3/s
scfm = scmps*60*(3.281**3)
print(f'The flow rate in scfm is {scfm:0.1f}')
# Out:
# The flow rate in scfm is 47.4

# %% [markdown]
# Why is this number different than the reported flow rate of CO2 through the relief valve? Could the diameter of the relief be slightly larger?

# %% [markdown]
# How would you get the generation rate of CO2 from the submlimation of dry ice?
#
# $$
# Q = hA(T_{water} - T_{ice}) \\
# mdot = Q/\Delta H_{vap}
# $$
#
# Does area ($A$) change? How would you get the heat transfer coefficient ($h$)?

# %% [markdown]
# ## In Class Example 2: More venting from a CO2 bottle

# %% [markdown]
# See text, in-class notes, and the python code here: https://github.com/clint-bg/safetybook/blob/main/Calcs.ipynb (after the Chapter 7 Heading)

# %% [markdown]
# ```{warning} Action Items
# 1. Determine the size of the vent needed for a 50 cubic meter tank filling with water at 5 kg/sec, assuming a MAWP of 1.5 barg and a discharge coefficient of 0.95.
# 2. Inside of a 100 cubic meter tank (half full of liquid), nitrogen is being generated at a constant rate of 1 mol per second. Determine the minimum diameter of a spring operated relief valve to prevent the over pressurization of the tank. The tank has an MAWP of 3.5 barg, and the nitrogen is generated at $40^\circ\text{C}$. Assume the valve vents to atmosphere and use a standard 10% overpressure for your calculations. Please calculate the recommended vent area (in mm) two different ways:
# - Using API 520 Equation given above (Eq. 1)
# - Using the orifice flow equations given in the Orifice Flow lecture, specifically the equation used for flow of gases through an orifice, equations also given above (Eq. 2 and 3).
# - Compare and comment on the two answers.
# ```
