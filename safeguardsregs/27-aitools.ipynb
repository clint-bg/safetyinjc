# %% [markdown]
# # AI Tools in Safety

# %% [markdown]
# ```{seealso} Learning Outcomes
# - Understand the basics of AI Tools
# - Be able to effectively use AI Tools in safety analysis
# ```

# %% [markdown]
# ```{note} Reading
# - Foundations of Spiritual and Physical Safety: with Chemical Processes; Chapter 11
# ```
